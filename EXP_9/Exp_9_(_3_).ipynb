# %% [markdown]
# <a href="https://colab.research.google.com/github/Nihal-18/ML/blob/master/EXP_9/Exp_9_(_3_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME: NIHAL M TODANKAR
#
# ROLL NO: J058
#
# TOPIC: Adult
#
# NO.: 13

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
train= pd.read_csv('/content/drive/My Drive/adult_data.csv')

test= pd.read_csv('/content/drive/My Drive/adults_test12.csv')

# %%
print('Train shape', train.shape)
print('\nTest shape', test.shape)
# Out:
# Train shape (20406, 15)
#
# Test shape (3833, 15)

# %%
train
# Out:
#        39          State-gov   77516  ...    40   United-States   <=50K
# 0      50   Self-emp-not-inc   83311  ...  13.0   United-States   <=50K
# 1      38            Private  215646  ...  40.0   United-States   <=50K
# 2      53            Private  234721  ...  40.0   United-States   <=50K
# 3      28            Private  338409  ...  40.0            Cuba   <=50K
# 4      37            Private  284582  ...  40.0   United-States   <=50K
# ...    ..                ...     ...  ...   ...             ...     ...
# 20401  26            Private  216010  ...  40.0   United-States   <=50K
# 20402  37            Private  164526  ...  40.0   United-States   <=50K
# 20403  27            Private  150958  ...  48.0       Guatemala   <=50K
# 20404  26            Private  244495  ...  48.0   United-States   <=50K
# 20405  23            Private  199336  ...   NaN             NaN     NaN
#
# [20406 rows x 15 columns]

# %%
test
# Out:
#       25            Private  226802  ...    40   United-States  <=50K.
# 0     38            Private   89814  ...  50.0   United-States  <=50K.
# 1     28          Local-gov  336951  ...  40.0   United-States   >50K.
# 2     44            Private  160323  ...  40.0   United-States   >50K.
# 3     18                  ?  103497  ...  30.0   United-States  <=50K.
# 4     34            Private  198693  ...  30.0   United-States  <=50K.
# ...   ..                ...     ...  ...   ...             ...     ...
# 3828  31            Private  257849  ...  40.0   United-States  <=50K.
# 3829  56            Private   50490  ...  40.0   United-States  <=50K.
# 3830  18            Private   85508  ...  12.0   United-States  <=50K.
# 3831  54   Self-emp-not-inc   60449  ...  60.0   United-States  <=50K.
# 3832  27          Local-gov  131310  ...   NaN             NaN     NaN
#
# [3833 rows x 15 columns]

# %%
train.isna().sum()
# Out:
# 39                0
#  State-gov        0
#  77516            0
#  Bachelors        0
#  13               0
#  Never-married    0
#  Adm-clerical     0
#  Not-in-family    1
#  White            1
#  Male             1
#  2174             1
#  0                1
#  40               1
#  United-States    1
#  <=50K            1
# dtype: int64

# %%
train= train.dropna()

train= train.reset_index(drop= True)

# %%
test.isna().sum()
# Out:
# 25                    0
#  Private              0
# 226802                0
# 11th                  0
# 7                     1
#  Never-married        1
#  Machine-op-inspct    1
#  Own-child            1
#  Black                1
#  Male                 1
# 0                     1
# 0.1                   1
# 40                    1
#  United-States        1
# <=50K.                1
# dtype: int64

# %%
test= test.dropna()

test= test.reset_index(drop= True)

# %%
test.isna().sum()
# Out:
# 25                    0
#  Private              0
# 226802                0
# 11th                  0
# 7                     0
#  Never-married        0
#  Machine-op-inspct    0
#  Own-child            0
#  Black                0
#  Male                 0
# 0                     0
# 0.1                   0
# 40                    0
#  United-States        0
# <=50K.                0
# dtype: int64

# %%
train.columns = ["Age", "Work_class", "fnlgwt","education","educaton_num","marital_status","occupation","relationship","race","sex","capital_gain","capital_loss","hours_per_week","native_country","output"]

# %%
train
# Out:
#        Age         Work_class  fnlgwt  ... hours_per_week  native_country  output
# 0       50   Self-emp-not-inc   83311  ...           13.0   United-States   <=50K
# 1       38            Private  215646  ...           40.0   United-States   <=50K
# 2       53            Private  234721  ...           40.0   United-States   <=50K
# 3       28            Private  338409  ...           40.0            Cuba   <=50K
# 4       37            Private  284582  ...           40.0   United-States   <=50K
# ...    ...                ...     ...  ...            ...             ...     ...
# 20400   42   Self-emp-not-inc  343609  ...           50.0   United-States   <=50K
# 20401   26            Private  216010  ...           40.0   United-States   <=50K
# 20402   37            Private  164526  ...           40.0   United-States   <=50K
# 20403   27            Private  150958  ...           48.0       Guatemala   <=50K
# ...

# %%
test.columns = ["Age", "Work_class", "fnlgwt","education","educaton_num","marital_status","occupation","relationship","race","sex","capital_gain","capital_loss","hours_per_week","native_country","output"]

# %%
test
# Out:
#       Age         Work_class  fnlgwt  ... hours_per_week  native_country  output
# 0      38            Private   89814  ...           50.0   United-States  <=50K.
# 1      28          Local-gov  336951  ...           40.0   United-States   >50K.
# 2      44            Private  160323  ...           40.0   United-States   >50K.
# 3      18                  ?  103497  ...           30.0   United-States  <=50K.
# 4      34            Private  198693  ...           30.0   United-States  <=50K.
# ...   ...                ...     ...  ...            ...             ...     ...
# 3827   36            Private  104213  ...           40.0   United-States  <=50K.
# 3828   31            Private  257849  ...           40.0   United-States  <=50K.
# 3829   56            Private   50490  ...           40.0   United-States  <=50K.
# 3830   18            Private   85508  ...           12.0   United-States  <=50K.
# 3831   54   Self-emp-not-inc   60449  ...           60.0   United-States  <=50K.
#
# ...

# %%
train['fnlgwt'].unique()
  print(1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   """Entry point for launching an IPython kernel.

# %%
for i in train.columns:
  print('\n\nColumn ',i,'Uniques= ',train[i].unique())
# Out:
# Column  Age Uniques=  [50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 39 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85]
#
#
# Column  Work_class Uniques=  [' Self-emp-not-inc' ' Private' ' State-gov' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#
#
# Column  fnlgwt Uniques=  [ 83311 215646 234721 ... 343609 150958 244495]
#
#
# Column  education Uniques=  [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
#
#
# Column  educaton_num Uniques=  [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
#
# Column  marital_status Uniques=  [' Married-civ-spouse' ' Divorced' ' Married-spouse-absent'
#  ' Never-married' ' Separated' ' Married-AF-spouse' ' Widowed']
#
#
# ...

# %%
l1= ['Work_class', 'native_country']

# %%
for i in test.columns:
  print('\n\nColumn ',i,'Uniques= ',test[i].unique())
# Out:
# Column  Age Uniques=  [38 28 44 18 34 29 63 24 55 65 36 26 58 48 43 20 37 40 72 25 45 22 23 54
#  32 46 56 17 39 52 21 42 33 30 47 41 19 69 50 31 59 49 51 27 57 61 64 79
#  73 53 77 80 62 35 68 66 75 60 67 71 70 90 81 74 78 82 83 85 76]
#
#
# Column  Work_class Uniques=  [' Private' ' Local-gov' ' ?' ' Self-emp-not-inc' ' Federal-gov'
#  ' State-gov' ' Self-emp-inc' ' Without-pay']
#
#
# Column  fnlgwt Uniques=  [ 89814 336951 160323 ...  50490  85508  60449]
#
#
# Column  education Uniques=  [' HS-grad' ' Assoc-acdm' ' Some-college' '10th' ' Prof-school' '7th-8th'
#  ' Bachelors' ' Masters' ' Doctorate' '11th' '5th-6th' ' Assoc-voc' '9th'
#  '12th' '1st-4th' ' Preschool']
#
#
# Column  educaton_num Uniques=  [ 9. 12. 10.  6. 15.  4. 13. 14. 16.  7.  3. 11.  5.  8.  2.  1.]
#
#
# Column  marital_status Uniques=  [' Married-civ-spouse' ' Never-married' ' Widowed' ' Divorced'
#  ' Separated' ' Married-spouse-absent' ' Married-AF-spouse']
#
#
# ...

# %%
train['num-of-doors'].replace('?','four',inplace=True)

# %%
for j in l1:

  train[j]= train[j].replace('?', np.nan, inplace= True)
  test[j]= test[j].replace('?', np.nan, inplace= True)

# %%
train.isna().sum()
# Out:
# Age                   0
# Work_class        20405
# fnlgwt                0
# education             0
# educaton_num          0
# marital_status        0
# occupation        20405
# relationship          0
# race                  0
# sex                   0
# capital_gain          0
# capital_loss          0
# hours_per_week        0
# native_country    20405
# output                0
# dtype: int64

# %%
train['occupation']= train['occupation'].replace('?', np.nan, inplace= True)

# %%
test['occupation']= test['occupation'].replace('?', np.nan, inplace= True)

# %%
train.isna().sum()
# Out:
# Age                   0
# Work_class        20405
# fnlgwt                0
# education             0
# educaton_num          0
# marital_status        0
# occupation        20405
# relationship          0
# race                  0
# sex                   0
# capital_gain          0
# capital_loss          0
# hours_per_week        0
# native_country    20405
# output                0
# dtype: int64

# %%
test.isna().sum()
# Out:
# Age                  0
# Work_class        3832
# fnlgwt               0
# education            0
# educaton_num         0
# marital_status       0
# occupation        3832
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country    3832
# output               0
# dtype: int64

# %%
((test['occupation'].isna().sum() )/ test.shape[0] ) *100
# Out:
# 100.0

# %%
test.shape[0]
# Out:
# 3832
